# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/THIRU/Documents/DATA SET/winequalityN.csv')

# %%
df.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
# 7  white            7.0              0.27         0.36            20.7
# 8  white            6.3              0.30         0.34             1.6
# 9  white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.shape
# Out:
# (6497, 13)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['type'].value_counts()
# Out:
# white    4870
# red      1593
# Name: type, dtype: int64

# %%
sns.boxplot(x='type',y='alcohol',data=df)
# Out:
# <Axes: xlabel='type', ylabel='alcohol'>

# %%
sns.distplot(df['alcohol'])
# Out:
# C:\Users\THIRU\AppData\Local\Temp\ipykernel_33440\2398698211.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['alcohol'])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.barplot(x='quality',y='alcohol',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.lmplot(x='fixed acidity',y='volatile acidity',data=df,fit_reg=False,hue='type',aspect=1)

# %%
sns.lmplot(x='pH',y='density',data=df,fit_reg=False,hue='type',aspect=1)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\THIRU\AppData\Local\Temp\ipykernel_33440\195471851.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.lmplot(x='fixed acidity',y='density',data=df,hue='type',aspect=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['type']=le.fit_transform(df['type'])

# %%
df.head()
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            7.0              0.27         0.36            20.7
# 1     1            6.3              0.30         0.34             1.6
# 2     1            8.1              0.28         0.40             6.9
# 3     1            7.2              0.23         0.32             8.5
# 4     1            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
X=df.drop(columns='quality',axis=1)

# %%
X.head()
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1            7.0              0.27         0.36            20.7
# 1     1            6.3              0.30         0.34             1.6
# 2     1            8.1              0.28         0.40             6.9
# 3     1            7.2              0.23         0.32             8.5
# 4     1            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol
# 0       0.45      8.8
# 1       0.49      9.5
# 2       0.44     10.1
# 3       0.40      9.9
# ...

# %%
y=df['quality']

# %%
y.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((4330, 12), (2133, 12))

# %%
y_train.shape, y_test.shape
# Out:
# ((4330,), (2133,))

# %%
# Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(X_test)

# %%
predictions
# Out:
# array([5.70116647, 5.61772428, 6.48944117, ..., 5.91675416, 6.12021468,
#        5.4988595 ])

# %%
# Evaluating the model

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.564137302033769
# MSE: 0.5149691972261135
# RMSE: 0.7176135430899513

# %%
# Ploting predictions vs actual values

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# Giving the model a sample data and predicting the quality value

# %%
sample=pd.DataFrame(df.iloc[0]).transpose()
sample
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1.0            7.0              0.27         0.36            20.7
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# 0      0.045                 45.0                 170.0    1.001  3.0
#
#    sulphates  alcohol  quality
# 0       0.45      8.8      6.0

# %%
s1=sample.drop(columns='quality',axis=1)
s1
# Out:
#    type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1.0            7.0              0.27         0.36            20.7
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# 0      0.045                 45.0                 170.0    1.001  3.0
#
#    sulphates  alcohol
# 0       0.45      8.8

# %%
s1=scaler.transform(s1)

# %%
sample_prediction=lm.predict(s1)

# %%
print(sample_prediction)
# Out:
# [5.63075422]
